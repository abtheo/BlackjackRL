# %% [markdown]
# <a href="https://colab.research.google.com/github/abtheo/BlackjackRL/blob/master/Blackjack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Black Jack
#
# ---

# %%
import random
import numpy as np
import keras
from keras.layers import *
from keras.models import *
from keras.optimizers import *
#import keras.backend as K
from keras import regularizers
from keras.callbacks import *

# %% [markdown]
# ##Cards & Deck

# %%
#Card / Deck module
class Deck:
    def __init__(self, cardList=None):
      self.all_suits = ['hearts', 'diamonds', 'spades', 'clubs']
      self.all_values = ['ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'jack', 'queen', 'king']

      if not cardList== None:
          self.cards = cardList
      else:
          self.cards = [Card(value, suit) for value in self.all_values for suit in self.all_suits]

    def __repr__(self):
        temp = []
        for c in self.cards:
            temp.append(c.value + "-" + c.suit)
        return ', '.join(temp)

    #Returns list of ALL cards with ANY properties
    def getAll(self, properties):
        out = []
        #Allows string to be passed
        if isinstance(properties, str):
            properties = [properties]
            
        for c in self.cards:
            for p in properties:
                if c.value == p or c.suit == p:
                    out.append(c)
                    break       
        return out

    #Returns list of cards with JUST properties
    def getSelect(self, values, suits):
        out = []
        #Allows strings to be passed
        if isinstance(values, str):
            values = [values]
        if isinstance(suits, str):
            suits = [suits]  
        for c in self.cards:
            for v in values:
                for s in suits:
                    if c.value == v and c.suit == s:
                        out.append(c)                   
        return out

    #Draw hand of N size
    def drawHand(self, hand_size=2):
      hand = Hand()
      for i in range(hand_size):
        card = random.choice(self.cards)
        hand.addCards(card)
        self.cards.remove(card)

      return hand

    #Draw card, removing from deck
    def drawCard(self):
      card = random.choice(self.cards)
      self.cards.remove(card)
      return card
     
       
class Card:
    def __init__(self, value, suit=None):
      self.all_suits = ['hearts', 'diamonds', 'spades', 'clubs']
      self.all_values = ['ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'jack', 'queen', 'king']
      self.points = 0

      if suit==None:
        suit = random.choice(self.all_suits)

      if value in self.all_values and suit in self.all_suits:
        self.value = value
        self.suit = suit

        self.points = self.valueToPoints(value)
      else:
        raise Exception('Invalid value {0} given for a playing card'.format(value))

    def __repr__(self):
        return "{0}-{1}".format(self.value, self.suit)

    def __int__(self):
      return self.points

    #Blackjack specific point encoding
    def valueToPoints(self, value):
      if not value in self.all_values:
        return None
      
      if value == 'jack' or value == 'queen' or value == 'king':
        return 10
      #Ace - what the fuck do I do here
      elif value == 'ace':
        return 11
      else:
        return int(value)

class Hand:
  def __init__(self, cards=None):
    self.cards = cards

  def __getitem___(self, key):
    if cards == None:
      raise Exception("No cards in hand, cannot get index")
    return self.cards[key]

  def __str__(self):
    return str(self.cards)
  
  def getPoints(self, cards=None):
    if cards == None:
      cards = self.cards

    total = sum([card.points for card in cards])
    
    card_values = [card.value for card in cards]
    if "ace" in card_values and total > 21:
      return total - 10
    else:
      return total

  def addCards(self, cards):
    #Allows single card to be passed
    if isinstance(cards, Card):
        cards = [cards]
    if self.cards == None:
      self.cards = cards
    else:
    #Concatenate to hand    
      self.cards += cards

# %% [markdown]
# #Agents

# %%
class RandomAgent():
  def __init__(self, hand=None):
    self.hand = hand
    self.action_space = [0,1,2] #Just Hit or Stick for now
    self.starting_bet = 10

  def setHand(self, hand):
    self.hand = hand
  
  def determineAction(self): #, game_state
    return random.choice(self.action_space)

#Hit on 16, Stand on 17
class Dealer():
  def __init__(self, hand=None):
    self.hand = hand
    self.end_state = 0

  def getShowingCard(self):
    return self.hand.cards[0]

  def setHand(self, hand):
    self.hand = hand
  
  def play_step(self, verbose):
    if hand == None:
      raise Exception("Dealer has no hand, cannot play.")

    points = self.hand.getPoints()
    if verbose > 0: print("Dealer points:", points)
    #Bust! Dealer loses
    if points > 21:
      if verbose > 0: print("Dealer Bust!")
      self.end_state =  -1
    #Stand on 17 +
    elif points >= 17:
      if verbose > 0: print("Dealer sticks.")
      self.end_state =  1
    #Hit on 16 - 
    else:
      if verbose > 0: print("Dealer hits!")
      self.end_state =  0

    

    

  def playRound(self, deck, verbose=0):
    if verbose > 0: print("Dealer has: ", self.hand.cards)
    while self.end_state == 0:
      self.play_step(verbose=verbose)

      if self.end_state == 0:
        new_card = deck.drawCard()
        self.hand.addCards(new_card)
        if verbose > 0: print("Dealer draws ", new_card)

    return self.end_state

# %%
#Instantialise deck of cards and dealer
deck = Deck()
dealer = Dealer()
#Draw 2 cards from deck
hand = deck.drawHand() 
#Give hand to Dealer
dealer.setHand(hand)
#Let Dealer play out round
dealer.playRound(deck)
# Out:
# 1

# %% [markdown]
# #Game Environment

# %%
class Game:
	def __init__(self, player=RandomAgent()):		
		self.deck = Deck()
		self.dealer = Dealer()
		self.player = player
		self.bet = 0
	
	def reset(self):
		self.deck = Deck()
		#Instatiate players and deal their hands
		self.player = RandomAgent(self.deck.drawHand(2))
		self.dealer = Dealer(self.deck.drawHand(2))

		self.bet = self.player.starting_bet

	def playDealerGame(self,verbose=0):		
		self.dealer_outcome = self.dealer.playRound(self.deck,verbose=verbose)

	def step(self, action, verbose=0):
		if verbose > 0:	print("Player has:", self.player.hand)
		#Player Hits
		if action == 0:
			#Draw card, add to player's hand
			card = self.deck.drawCard()
			self.player.hand.addCards(card)
			player_bust = self.isHandBust(self.player.hand)
			if verbose > 0:
				print("Player draws: ", card)
				print("Player points: ", self.player.hand.getPoints())

			if player_bust:
				#Observation, reward, done
				return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points], -self.bet, -1)
			else:
				return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points], 1, 0)


		#Player Sticks
		elif action == 1:
			if verbose > 0: print("Player sticks on ", self.player.hand.getPoints())
			
	 		#Dealer sticks
			if self.dealer_outcome > 0:
				#Dealer wins
				if self.dealer.hand.getPoints() >= self.player.hand.getPoints():
					return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points] , -self.bet, -1)
				else:
				#Dealer loses
					return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points] , self.bet, 1)

		 		#Dealer loses
			else:
				return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points] , self.bet, 1)

		#Action == 2:
		#Double Down - Bet 2x, hit once and stick.
		elif action == 2:
			if verbose > 0: print("Player Doubles Down!")# 
			#Draw card, add to player's hand
			card = self.deck.drawCard()
			self.player.hand.addCards(card)
			player_bust = self.isHandBust(self.player.hand)
	 
			if verbose > 0:
				print("Player draws: ", card)
				print("Player points: ", self.player.hand.getPoints())
				print("Player Bust? ", player_bust)
		
			if player_bust:
				#Observation, reward, done
				return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points], -self.bet*2, -1)

			#Dealer sticks
			if self.dealer_outcome > 0:
				#Dealer wins
				if self.dealer.hand.getPoints() >= self.player.hand.getPoints():
					return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points] , -self.bet*2, -1)
				else:
				#Dealer loses
					return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points] , self.bet*2, 1)

		 		#Dealer bust
			else:
				return ([self.player.hand.getPoints(), self.dealer.getShowingCard().points] , self.bet*2, 1)



	def isHandBust(self, hand):
		if hand == None:
			raise Exception("None hand given to evaluation function")

		points = hand.getPoints()
		#Bust! Player loses
		if points > 21:
			return True
		#Game can continue
		else:
			return False
		
  # def step(self, action):
	# 	next_state, value, done = self.gameState.takeAction(action)
	# 	self.gameState = next_state
	# 	self.currentPlayer = -self.currentPlayer
	# 	info = None
	# 	return ((next_state, value, done, info))

# %% [markdown]
# #Main Loop

# %%
env = Game()
game_memory = []

for i in range(10):
  env.reset()
  done = 0

  env.playDealerGame()
  prev_obs = [env.player.hand.getPoints(), env.dealer.getShowingCard().points]
  while done == 0:
    action = env.player.determineAction()
    #print("Action: ", action)
    
    observation, reward, done = env.step(action)

    one_hot_action = [1,0] if action == 0 else [0,1]
    if reward >= 1:
      game_memory.append([prev_obs, one_hot_action])

    prev_obs = observation

print(game_memory)
# Out:
# [[[12, 10], [1, 0]], [[15, 10], [0, 1]], [[17, 3], [0, 1]], [[8, 7], [1, 0]], [[14, 3], [1, 0]], [[16, 3], [0, 1]], [[4, 10], [1, 0]], [[17, 10], [1, 0]], [[18, 10], [0, 1]]]

# %% [markdown]
# #Training Data

# %%
X = np.array(game_memory)[:,0]
Y = np.array(game_memory)[:,1]

X = X.reshape((-1, 2))
print(X.shape, Y.shape)

# %% [markdown]
# #Model Definition

# %%
#Returns a compiled neural network model, ready for training
def build_nn_model(features=2, out_shape=3):  
  input_layer = Input(shape=[features])
  x = Dense(128, activation='relu', kernel_regularizer=regularizers.l1_l2(0.001,0.001))(input_layer)
  x = Dropout(rate=0.2)(x)

  x = Dense(256,activation='relu', kernel_regularizer=regularizers.l1_l2(0.001,0.001))(x)
  x = Dropout(rate=0.2)(x)

  x = Dense(128, activation='relu', kernel_regularizer=regularizers.l1_l2(0.001,0.001))(x)
  x = Dropout(rate=0.2)(x)

  output_layer = Dense(out_shape, activation='softmax')(x)

  model = Model(inputs = input_layer, outputs = output_layer)

  model.compile(optimizer=Adam(lr=0.0001, decay=1e-6),
                loss=['categorical_crossentropy'])
  
  return model

# %%
model = build_nn_model()

history = model.fit(X, Y, validation_split=0.2, batch_size=32, epochs=7)

# %%
x = np.array([[1, 10]])

model.predict(x)
#print(X[0].ravel().shape)

# %% [markdown]
# #Main Loop with Basic Model

# %%
env = Game()
game_memory = []

player_wins = []
for i in range(1000):
  print("========= STARTING =========")
  env.reset()
  done = 0
  print("======== DEALER TURN ========")
  env.playDealerGame(verbose=2)
  prev_obs = [env.player.hand.getPoints(), env.dealer.getShowingCard().points]
  
  print("======== PLAYER TURN ========")
  while done == 0:

    #action = env.player.determineAction()
    np_state = np.array([prev_obs])
    action = np.argmax(model.predict(np_state))

    #print("Action: ", action)
    
    observation, reward, done = env.step(action, verbose=12)

    # one_hot_action = [0,1] if action == 0 else [1,0]
    # if reward >= 1:
    #   game_memory.append([prev_obs, one_hot_action])

    prev_obs = observation

    if done == 1:
      print("WINNER ////// Player won!")
      player_wins.append(1)
    elif done == -1:
      print("WINNER +++++ Dealer won!")
      player_wins.append(0) 

print(sum(player_wins) / len(player_wins) * 100)
#print(game_memory)

# %% [markdown]
# #DQN Agent

# %%
from collections import deque
from sklearn.preprocessing import OneHotEncoder

REPLAY_MAX_SIZE = 50_000
REPLAY_MIN_SIZE = 128
MINIBATCH_SIZE = 64
UPDATE_EVERY = 5
DISCOUNT = 0.99
norm = 30 #Max hand point value to normalize states
action_space = [0,1,2] #Hit, Stick, Double_down


class DQNAgent:
  def __init__(self, hand=None):
    self.hand = hand
    self.action_space = action_space#Just Hit or Stick for now
    self.starting_bet = 10
    #Main model
    self.model = build_nn_model(features=2, out_shape = len(self.action_space))

    #Target model
    self.target_model = build_nn_model(features=2, out_shape = len(self.action_space))
    self.target_model.set_weights(self.model.get_weights())
    self.target_update_counter = 0
    
    #Replay Memory
    self.replay_memory = deque(maxlen=REPLAY_MAX_SIZE)


  def setHand(self, hand):
    self.hand = hand
    
  #Transition = (s0, a, r, s1, d)
  def update_replay_memory(self, transition):
    self.replay_memory.append(transition)

  def get_Q(self, state):
    return self.model.predict(np.array(state))[0]

  def train(self, terminal_state, step):
    if len(self.replay_memory) < REPLAY_MIN_SIZE:
      return

    minibatch = random.sample(self.replay_memory, MINIBATCH_SIZE)

    current_states = np.array([transition[0] for transition in minibatch]) / norm
    current_qs_list = self.model.predict(current_states)

    new_current_states = np.array([transition[3] for transition in minibatch]) / norm
    future_qs_list = self.target_model.predict(new_current_states)

    X = []
    y = []

    for index, (state, action, reward, new_state, done) in enumerate(minibatch):
      if not done:
        max_future_Q = np.max(future_qs_list[index])
        new_Q = reward + DISCOUNT * max_future_Q
      else:
        new_Q = reward

      current_qs = current_qs_list[index]
      current_qs[action] = new_Q

      X.append(state)
      y.append(current_qs)

    self.model.fit(np.array(X)/norm, np.array(y), batch_size=MINIBATCH_SIZE, verbose=0, shuffle=False)

    #If done, i.e. done != 0
    if not terminal_state == 0:
      self.target_update_counter += 1

    if self.target_update_counter > UPDATE_EVERY:
      self.target_model.set_weights(self.model.get_weights())
      self.target_update_counter = 0

# %% [markdown]
# #Train DQN

# %%
from tqdm import tqdm
player_wins = []


#Explortation
epsilon = 1
EPSILON_DECAY = 0.99995
MIN_EPSILON = 0.01

#agent = DQNAgent()
env = Game()
for i in range(100_000):
  #print("========= STARTING =========")
  env.reset()
  done = 0
  reward = 0
  score = 0
  step = 1
  #print("======== DEALER TURN ========")
  env.playDealerGame(verbose=0)
  state = [env.player.hand.getPoints(), env.dealer.getShowingCard().points]
  
  #print("======== PLAYER TURN ========")
  while done == 0:

    np_state = np.array([state]) / norm

    if np.random.random() > epsilon:
      action = np.argmax(agent.get_Q(np_state))
    else:
      action = np.random.randint(0, len(agent.action_space))
    
    new_state, reward, done = env.step(action, verbose=0)

    score += reward

    agent.update_replay_memory((state, action, score, new_state, done))
    agent.train(done, step)

    state = new_state
    step += 1

  if (i) % 1000 == 0:
    print(i)

  # Decay epsilon
  if epsilon > MIN_EPSILON:
      epsilon *= EPSILON_DECAY
      epsilon = max(MIN_EPSILON, epsilon)

#print(sum(player_wins) / len(player_wins) * 100)
#print(game_memory)

# %% [markdown]
# #Test DQN

# %%
env = Game()
player_wins = []
wallet = 0
for i in range(1000):
  print("========= STARTING =========")
  env.reset()
  done = 0
  print("======== DEALER TURN ========")
  env.playDealerGame(verbose=2)
  state = [env.player.hand.getPoints(), env.dealer.getShowingCard().points]
  score = 0
  wage = 0
  print("======== PLAYER TURN ========")
  while done == 0:

    np_state = np.array([state]) / norm

    action = np.argmax(agent.get_Q(np_state))
    print(agent.get_Q(np_state))
    
    new_state, reward, done = env.step(action, verbose=12)
    
    score += reward

    state = new_state

    if not reward==1:
      wage += reward


  if done == 1:
    print("WINNER ////// Player won!")
  elif done == -1:
    print("WINNER +++++ Dealer won!")

  player_wins.append(score)
  wallet += wage

print(np.mean(player_wins))
print(wallet)
#print(sum(player_wins) / len(player_wins) * 100)
#print(game_memory)
# Out:
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-diamonds, 2-clubs]
# Dealer points: 8
# Dealer hits!
# Dealer draws  ace-clubs
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.000000e+00 1.000000e+00 5.890672e-35]
# Player has: [5-spades, 9-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, jack-clubs]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 2.1733822e-35]
# Player has: [6-hearts, 8-diamonds]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-clubs, 2-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  jack-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [3-diamonds, queen-diamonds]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-spades, 8-spades]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3476506e-09 3.0360627e-11]
# Player has: [7-clubs, 4-clubs]
# Player draws:  9-diamonds
# Player points:  20
# [0. 1. 0.]
# Player has: [7-clubs, 4-clubs, 9-diamonds]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-clubs, 9-diamonds]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3480978e-09 3.0363580e-11]
# Player has: [4-diamonds, 2-spades]
# Player draws:  10-spades
# Player points:  16
# [0. 1. 0.]
# Player has: [4-diamonds, 2-spades, 10-spades]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-diamonds, 4-clubs]
# Dealer points: 14
# Dealer hits!
# Dealer draws  2-hearts
# Dealer points: 16
# Dealer hits!
# Dealer draws  6-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-hearts, 7-clubs]
# Player sticks on  17
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-clubs, ace-hearts]
# Dealer points: 13
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-hearts, jack-hearts]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-spades, jack-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  ace-hearts
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.993640e-06 9.999980e-01 3.121356e-11]
# Player has: [2-hearts, queen-diamonds]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-spades, 9-hearts]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-hearts, 6-clubs]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-diamonds, 2-clubs]
# Dealer points: 13
# Dealer hits!
# Dealer draws  5-clubs
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.223311e-07 9.999999e-01 5.925380e-12]
# Player has: [10-clubs, 2-spades]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-hearts, jack-hearts]
# Dealer points: 15
# Dealer hits!
# Dealer draws  5-spades
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [4.678147e-26 1.000000e+00 5.979275e-23]
# Player has: [ace-diamonds, 2-diamonds]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-clubs, 8-diamonds]
# Dealer points: 11
# Dealer hits!
# Dealer draws  7-hearts
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.4288629e-25 1.0000000e+00 1.1623506e-22]
# Player has: [3-diamonds, king-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-clubs, queen-spades]
# Dealer points: 15
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-clubs, king-spades]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-clubs, jack-diamonds]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-hearts, 10-spades]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-diamonds, ace-clubs]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [5-hearts, 7-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-clubs, 9-clubs]
# Dealer points: 14
# Dealer hits!
# Dealer draws  6-hearts
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 8.2132795e-35]
# Player has: [4-clubs, 10-diamonds]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-diamonds, 6-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  2-spades
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-spades, king-spades]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-diamonds, 2-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  ace-hearts
# Dealer points: 13
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-clubs, queen-hearts]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-hearts, ace-diamonds]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [queen-spades, 3-clubs]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-clubs, king-hearts]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-clubs, 7-spades]
# Player sticks on  15
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-hearts, jack-diamonds]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3475613e-09 3.0358716e-11]
# Player has: [5-diamonds, 6-diamonds]
# Player draws:  2-spades
# Player points:  13
# [1.5316534e-26 1.0000000e+00 3.0758245e-23]
# Player has: [5-diamonds, 6-diamonds, 2-spades]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-spades, 4-diamonds]
# Dealer points: 10
# Dealer hits!
# Dealer draws  8-hearts
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-spades, king-hearts]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-diamonds, jack-clubs]
# Dealer points: 16
# Dealer hits!
# Dealer draws  ace-spades
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-clubs, 5-clubs]
# Player sticks on  15
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-hearts, queen-hearts]
# Dealer points: 14
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [8.1759615e-26 1.0000000e+00 8.3367534e-23]
# Player has: [7-clubs, 6-spades]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-hearts, 4-diamonds]
# Dealer points: 11
# Dealer hits!
# Dealer draws  2-clubs
# Dealer points: 13
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-clubs, ace-hearts]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-clubs, 9-hearts]
# Dealer points: 14
# Dealer hits!
# Dealer draws  6-clubs
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3481296e-09 3.0363927e-11]
# Player has: [7-clubs, 3-diamonds]
# Player draws:  10-spades
# Player points:  20
# [0. 1. 0.]
# Player has: [7-clubs, 3-diamonds, 10-spades]
# Player sticks on  20
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-hearts, 3-spades]
# Dealer points: 13
# Dealer hits!
# Dealer draws  ace-hearts
# Dealer points: 14
# Dealer hits!
# Dealer draws  6-spades
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-clubs, king-diamonds]
# Player sticks on  20
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-diamonds, 4-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  10-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 3.0302462e-35]
# Player has: [4-diamonds, jack-clubs]
# Player sticks on  14
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-diamonds, 2-diamonds]
# Dealer points: 7
# Dealer hits!
# Dealer draws  queen-spades
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.4816862e-06 9.9999654e-01 4.3503461e-11]
# Player has: [2-hearts, king-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-clubs, 4-clubs]
# Dealer points: 7
# Dealer hits!
# Dealer draws  4-diamonds
# Dealer points: 11
# Dealer hits!
# Dealer draws  5-clubs
# Dealer points: 16
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-spades, 5-spades]
# Player sticks on  15
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-hearts, 9-clubs]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-diamonds, 7-diamonds]
# Player sticks on  17
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-hearts, 7-clubs]
# Dealer points: 15
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-spades, ace-clubs]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, 7-spades]
# Dealer points: 16
# Dealer hits!
# Dealer draws  5-diamonds
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.000000e+00 3.348155e-09 3.036416e-11]
# Player has: [3-hearts, 5-clubs]
# Player draws:  6-spades
# Player points:  14
# [0.0000000e+00 1.0000000e+00 2.1733822e-35]
# Player has: [3-hearts, 5-clubs, 6-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-clubs, 8-hearts]
# Dealer points: 16
# Dealer hits!
# Dealer draws  jack-diamonds
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, 5-clubs]
# Player sticks on  15
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-diamonds, 4-hearts]
# Dealer points: 10
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.993640e-06 9.999980e-01 3.121356e-11]
# Player has: [2-hearts, 10-hearts]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-spades, 10-clubs]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-hearts, queen-diamonds]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-hearts, king-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  king-hearts
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-clubs, queen-clubs]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-spades, 10-diamonds]
# Dealer points: 13
# Dealer hits!
# Dealer draws  queen-hearts
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-diamonds, ace-hearts]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-diamonds, jack-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  8-clubs
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-spades, queen-clubs]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-hearts, queen-clubs]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [4-spades, queen-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-spades, 2-diamonds]
# Dealer points: 4
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 12
# Dealer hits!
# Dealer draws  king-spades
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 2.2261204e-34]
# Player has: [6-spades, 8-hearts]
# Player sticks on  14
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-diamonds, 4-spades]
# Dealer points: 9
# Dealer hits!
# Dealer draws  king-spades
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-diamonds, 7-hearts]
# Player sticks on  17
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-clubs, queen-clubs]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [8-hearts, 6-hearts]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-hearts, 9-spades]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.7363861e-07 9.9999964e-01 1.1518690e-11]
# Player has: [2-diamonds, king-diamonds]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-diamonds, 10-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  6-hearts
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-hearts, 9-spades]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-diamonds, 6-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  ace-diamonds
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-hearts, 9-hearts]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-diamonds, 8-diamonds]
# Dealer points: 15
# Dealer hits!
# Dealer draws  5-spades
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-spades, 8-spades]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-diamonds, 2-diamonds]
# Dealer points: 5
# Dealer hits!
# Dealer draws  8-clubs
# Dealer points: 13
# Dealer hits!
# Dealer draws  7-diamonds
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3480785e-09 3.0363351e-11]
# Player has: [4-hearts, 6-hearts]
# Player draws:  2-hearts
# Player points:  12
# [1.0618807e-05 9.9998939e-01 8.4505423e-11]
# Player has: [4-hearts, 6-hearts, 2-hearts]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-spades, queen-spades]
# Dealer points: 16
# Dealer hits!
# Dealer draws  4-clubs
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-hearts, ace-hearts]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-spades, queen-spades]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-diamonds, 9-spades]
# Player sticks on  20
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-spades, 3-diamonds]
# Dealer points: 13
# Dealer hits!
# Dealer draws  3-clubs
# Dealer points: 16
# Dealer hits!
# Dealer draws  10-spades
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3476506e-09 3.0360627e-11]
# Player has: [5-hearts, 6-spades]
# Player draws:  10-hearts
# Player points:  21
# [0. 1. 0.]
# Player has: [5-hearts, 6-spades, 10-hearts]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-hearts, 3-clubs]
# Dealer points: 11
# Dealer hits!
# Dealer draws  king-spades
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-diamonds, jack-hearts]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-diamonds, 7-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-spades, 5-spades]
# Player sticks on  15
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-clubs, 4-spades]
# Dealer points: 9
# Dealer hits!
# Dealer draws  8-spades
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.4816862e-06 9.9999654e-01 4.3503461e-11]
# Player has: [2-spades, 10-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-hearts, 9-spades]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482637e-09 3.0365377e-11]
# Player has: [2-hearts, 8-spades]
# Player draws:  10-spades
# Player points:  20
# [0. 1. 0.]
# Player has: [2-hearts, 8-spades, 10-spades]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-clubs, 4-clubs]
# Dealer points: 14
# Dealer hits!
# Dealer draws  9-clubs
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [2-clubs, king-spades]
# Player sticks on  12
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, 9-spades]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [5.0146871e-27 1.0000000e+00 1.5822423e-23]
# Player has: [2-spades, ace-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-clubs, ace-hearts]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-clubs, jack-diamonds]
# Player sticks on  20
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-clubs, jack-spades]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.7363861e-07 9.9999964e-01 1.1518690e-11]
# Player has: [10-diamonds, 2-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-hearts, 4-clubs]
# Dealer points: 14
# Dealer hits!
# Dealer draws  2-clubs
# Dealer points: 16
# Dealer hits!
# Dealer draws  king-diamonds
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482892e-09 3.0365724e-11]
# Player has: [2-hearts, 8-hearts]
# Player draws:  jack-spades
# Player points:  20
# [0. 1. 0.]
# Player has: [2-hearts, 8-hearts, jack-spades]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-hearts, 7-clubs]
# Dealer points: 11
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3480978e-09 3.0363639e-11]
# Player has: [4-spades, 6-spades]
# Player draws:  jack-clubs
# Player points:  20
# [0. 1. 0.]
# Player has: [4-spades, 6-spades, jack-clubs]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-hearts, jack-diamonds]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-diamonds, ace-hearts]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-hearts, 6-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  3-hearts
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-clubs, 9-hearts]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-hearts, 8-clubs]
# Dealer points: 16
# Dealer hits!
# Dealer draws  jack-spades
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-diamonds, queen-hearts]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-clubs, 3-diamonds]
# Dealer points: 12
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-spades, ace-spades]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, king-spades]
# Dealer points: 14
# Dealer hits!
# Dealer draws  queen-hearts
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-spades, 9-spades]
# Player sticks on  17
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-spades, ace-diamonds]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482379e-09 3.0365085e-11]
# Player has: [2-hearts, 7-hearts]
# Player draws:  5-clubs
# Player points:  14
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [2-hearts, 7-hearts, 5-clubs]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-diamonds, ace-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  10-clubs
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.6418387e-27 1.0000000e+00 8.1393114e-24]
# Player has: [3-diamonds, king-spades]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-hearts, 8-hearts]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3476122e-09 3.0359874e-11]
# Player has: [4-diamonds, 7-diamonds]
# Player draws:  ace-diamonds
# Player points:  12
# [3.7363861e-07 9.9999964e-01 1.1518690e-11]
# Player has: [4-diamonds, 7-diamonds, ace-diamonds]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-diamonds, queen-diamonds]
# Dealer points: 12
# Dealer hits!
# Dealer draws  king-diamonds
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-hearts, 8-spades]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-diamonds, 7-hearts]
# Dealer points: 15
# Dealer hits!
# Dealer draws  queen-clubs
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [6.5299395e-07 9.9999940e-01 1.6060094e-11]
# Player has: [king-diamonds, 2-clubs]
# Player sticks on  12
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-diamonds, 8-diamonds]
# Dealer points: 13
# Dealer hits!
# Dealer draws  ace-hearts
# Dealer points: 14
# Dealer hits!
# Dealer draws  queen-spades
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-clubs, 10-spades]
# Player sticks on  17
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-spades, 7-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  8-spades
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.4816862e-06 9.9999654e-01 4.3503461e-11]
# Player has: [7-clubs, 5-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-clubs, 10-spades]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [8.7639296e-27 1.0000000e+00 2.2060386e-23]
# Player has: [3-clubs, king-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-clubs, 5-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  queen-hearts
# Dealer points: 16
# Dealer hits!
# Dealer draws  ace-spades
# Dealer points: 27
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-spades, 7-hearts]
# Player sticks on  17
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-clubs, 2-spades]
# Dealer points: 6
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 14
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [6.080428e-06 9.999939e-01 6.063249e-11]
# Player has: [5-diamonds, 7-clubs]
# Player sticks on  12
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-spades, jack-clubs]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.1180274e-35]
# Player has: [ace-diamonds, 3-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-hearts, jack-diamonds]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-spades, 7-spades]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-hearts, 6-spades]
# Dealer points: 16
# Dealer hits!
# Dealer draws  king-spades
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [4-spades, 10-spades]
# Player sticks on  14
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-diamonds, 10-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [8.7639296e-27 1.0000000e+00 2.2060386e-23]
# Player has: [9-spades, 4-clubs]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-hearts, 6-spades]
# Dealer points: 8
# Dealer hits!
# Dealer draws  jack-diamonds
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-clubs, queen-diamonds]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-spades, 6-clubs]
# Dealer points: 13
# Dealer hits!
# Dealer draws  4-hearts
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3480274e-09 3.0362771e-11]
# Player has: [4-spades, 2-clubs]
# Player draws:  6-spades
# Player points:  12
# [1.1412177e-06 9.9999881e-01 2.2392007e-11]
# Player has: [4-spades, 2-clubs, 6-spades]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-diamonds, 7-clubs]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-spades, king-hearts]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-clubs, 7-diamonds]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-spades, 8-diamonds]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-spades, 10-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-clubs, 10-diamonds]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-spades, 3-clubs]
# Dealer points: 10
# Dealer hits!
# Dealer draws  9-clubs
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-hearts, ace-spades]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-spades, jack-diamonds]
# Dealer points: 12
# Dealer hits!
# Dealer draws  jack-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3480465e-09 3.0363000e-11]
# Player has: [2-diamonds, 8-clubs]
# Player draws:  8-diamonds
# Player points:  18
# [0. 1. 0.]
# Player has: [2-diamonds, 8-clubs, 8-diamonds]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-diamonds, 5-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  4-diamonds
# Dealer points: 16
# Dealer hits!
# Dealer draws  king-diamonds
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-clubs, 10-diamonds]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-clubs, queen-diamonds]
# Dealer points: 14
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3479699e-09 3.0362074e-11]
# Player has: [2-clubs, 4-spades]
# Player draws:  5-clubs
# Player points:  11
# [1.0000000e+00 3.3477083e-09 3.0359760e-11]
# Player has: [2-clubs, 4-spades, 5-clubs]
# Player draws:  10-clubs
# Player points:  21
# [0. 1. 0.]
# Player has: [2-clubs, 4-spades, 5-clubs, 10-clubs]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, 8-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  8-clubs
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-hearts, ace-diamonds]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-spades, queen-diamonds]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.7363861e-07 9.9999964e-01 1.1518690e-11]
# Player has: [6-clubs, 6-diamonds]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-clubs, 5-hearts]
# Dealer points: 15
# Dealer hits!
# Dealer draws  4-spades
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-clubs, 10-clubs]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-diamonds, 5-hearts]
# Dealer points: 15
# Dealer hits!
# Dealer draws  ace-diamonds
# Dealer points: 16
# Dealer hits!
# Dealer draws  6-spades
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [ace-spades, 2-spades]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-hearts, king-spades]
# Dealer points: 15
# Dealer hits!
# Dealer draws  queen-spades
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [4.678147e-26 1.000000e+00 5.979275e-23]
# Player has: [ace-hearts, 2-diamonds]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-spades, 2-clubs]
# Dealer points: 4
# Dealer hits!
# Dealer draws  king-clubs
# Dealer points: 14
# Dealer hits!
# Dealer draws  6-clubs
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-hearts, ace-hearts]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, 7-hearts]
# Dealer points: 16
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-clubs, 10-clubs]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-clubs, queen-hearts]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [5.0146871e-27 1.0000000e+00 1.5822423e-23]
# Player has: [10-hearts, 3-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-diamonds, 7-clubs]
# Dealer points: 15
# Dealer hits!
# Dealer draws  7-spades
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-diamonds, queen-spades]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-diamonds, 2-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  4-diamonds
# Dealer points: 16
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [2-diamonds, jack-spades]
# Player sticks on  12
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-clubs, 6-spades]
# Dealer points: 10
# Dealer hits!
# Dealer draws  5-diamonds
# Dealer points: 15
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-diamonds, king-hearts]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, 8-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  ace-diamonds
# Dealer points: 13
# Dealer hits!
# Dealer draws  7-hearts
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-diamonds, king-spades]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-hearts, 7-hearts]
# Dealer points: 10
# Dealer hits!
# Dealer draws  king-clubs
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3479699e-09 3.0362074e-11]
# Player has: [4-clubs, 3-clubs]
# Player draws:  8-spades
# Player points:  15
# [0. 1. 0.]
# Player has: [4-clubs, 3-clubs, 8-spades]
# Player sticks on  15
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-spades, 5-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  6-hearts
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-hearts, queen-diamonds]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-diamonds, ace-diamonds]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482892e-09 3.0365724e-11]
# Player has: [3-diamonds, 7-hearts]
# Player draws:  ace-clubs
# Player points:  21
# [0. 1. 0.]
# Player has: [3-diamonds, 7-hearts, ace-clubs]
# Player sticks on  21
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-hearts, king-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-diamonds, jack-diamonds]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-spades, 5-hearts]
# Dealer points: 7
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 16
# Dealer hits!
# Dealer draws  6-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.8544457e-05 9.9998140e-01 1.1777747e-10]
# Player has: [2-hearts, queen-clubs]
# Player sticks on  12
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-clubs, queen-diamonds]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3481360e-09 3.0363927e-11]
# Player has: [5-clubs, 2-clubs]
# Player draws:  6-hearts
# Player points:  13
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [5-clubs, 2-clubs, 6-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-clubs, 2-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  queen-spades
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-hearts, ace-diamonds]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-clubs, ace-spades]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482892e-09 3.0365724e-11]
# Player has: [5-spades, 5-hearts]
# Player draws:  3-clubs
# Player points:  13
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [5-spades, 5-hearts, 3-clubs]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-spades, 6-diamonds]
# Dealer points: 13
# Dealer hits!
# Dealer draws  jack-spades
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, 8-hearts]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-hearts, 3-clubs]
# Dealer points: 9
# Dealer hits!
# Dealer draws  7-spades
# Dealer points: 16
# Dealer hits!
# Dealer draws  jack-hearts
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0.000000e+00 1.000000e+00 5.890672e-35]
# Player has: [4-spades, queen-hearts]
# Player sticks on  14
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, jack-spades]
# Dealer points: 14
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-diamonds, 7-hearts]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-hearts, queen-spades]
# Dealer points: 12
# Dealer hits!
# Dealer draws  jack-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 2.2261204e-34]
# Player has: [6-diamonds, 8-clubs]
# Player sticks on  14
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-spades, jack-hearts]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [3.7363861e-07 9.9999964e-01 1.1518690e-11]
# Player has: [king-clubs, 2-hearts]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-clubs, 4-clubs]
# Dealer points: 10
# Dealer hits!
# Dealer draws  5-clubs
# Dealer points: 15
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 23
# Dealer Bust!
# ======== PLAYER TURN ========
# [2.6767973e-26 1.0000000e+00 4.2884801e-23]
# Player has: [10-diamonds, 3-spades]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-spades, 8-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  4-hearts
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 3.0302462e-35]
# Player has: [5-spades, 9-diamonds]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-spades, 9-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-diamonds, 7-diamonds]
# Player sticks on  17
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-clubs, 3-spades]
# Dealer points: 12
# Dealer hits!
# Dealer draws  10-spades
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, 9-hearts]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, 3-diamonds]
# Dealer points: 12
# Dealer hits!
# Dealer draws  5-diamonds
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-hearts, 7-spades]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-spades, 6-spades]
# Dealer points: 16
# Dealer hits!
# Dealer draws  6-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482892e-09 3.0365724e-11]
# Player has: [2-hearts, 8-diamonds]
# Player draws:  3-spades
# Player points:  13
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [2-hearts, 8-diamonds, 3-spades]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-diamonds, 3-diamonds]
# Dealer points: 5
# Dealer hits!
# Dealer draws  8-hearts
# Dealer points: 13
# Dealer hits!
# Dealer draws  3-hearts
# Dealer points: 16
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-diamonds, 8-clubs]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-spades, 6-spades]
# Dealer points: 10
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 16
# Dealer hits!
# Dealer draws  queen-spades
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [6.080428e-06 9.999939e-01 6.063249e-11]
# Player has: [4-hearts, 8-spades]
# Player sticks on  12
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-spades, king-diamonds]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482379e-09 3.0365085e-11]
# Player has: [2-spades, 7-clubs]
# Player draws:  4-hearts
# Player points:  13
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [2-spades, 7-clubs, 4-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-spades, 9-diamonds]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482379e-09 3.0365085e-11]
# Player has: [6-clubs, 3-diamonds]
# Player draws:  3-clubs
# Player points:  12
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [6-clubs, 3-diamonds, 3-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-hearts, jack-spades]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-spades, 10-diamonds]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-diamonds, jack-clubs]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [4-hearts, king-clubs]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-clubs, 6-clubs]
# Dealer points: 11
# Dealer hits!
# Dealer draws  10-hearts
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 8.2132795e-35]
# Player has: [9-spades, 5-diamonds]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-spades, 7-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-hearts, king-hearts]
# Player sticks on  17
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-diamonds, 8-spades]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3481871e-09 3.0364506e-11]
# Player has: [4-diamonds, 4-spades]
# Player draws:  7-hearts
# Player points:  15
# [0. 1. 0.]
# Player has: [4-diamonds, 4-spades, 7-hearts]
# Player sticks on  15
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, 2-diamonds]
# Dealer points: 6
# Dealer hits!
# Dealer draws  10-clubs
# Dealer points: 16
# Dealer hits!
# Dealer draws  3-clubs
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [8.1759615e-26 1.0000000e+00 8.3367534e-23]
# Player has: [4-hearts, 9-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-hearts, 7-spades]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, 5-hearts]
# Player sticks on  15
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-hearts, 3-hearts]
# Dealer points: 13
# Dealer hits!
# Dealer draws  3-spades
# Dealer points: 16
# Dealer hits!
# Dealer draws  5-diamonds
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3476506e-09 3.0360627e-11]
# Player has: [8-spades, 3-diamonds]
# Player draws:  ace-spades
# Player points:  12
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [8-spades, 3-diamonds, ace-spades]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-clubs, queen-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  5-diamonds
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-clubs, 9-diamonds]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-diamonds, king-hearts]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [ace-clubs, 3-diamonds]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-diamonds, 7-clubs]
# Dealer points: 10
# Dealer hits!
# Dealer draws  8-diamonds
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.4288629e-25 1.0000000e+00 1.1623506e-22]
# Player has: [jack-hearts, 3-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-clubs, 2-diamonds]
# Dealer points: 9
# Dealer hits!
# Dealer draws  10-spades
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3481935e-09 3.0364621e-11]
# Player has: [4-spades, 6-clubs]
# Player draws:  4-hearts
# Player points:  14
# [0.0000000e+00 1.0000000e+00 4.2249962e-35]
# Player has: [4-spades, 6-clubs, 4-hearts]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-hearts, 3-hearts]
# Dealer points: 8
# Dealer hits!
# Dealer draws  3-clubs
# Dealer points: 11
# Dealer hits!
# Dealer draws  jack-clubs
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [4.678147e-26 1.000000e+00 5.979275e-23]
# Player has: [8-spades, 5-clubs]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-diamonds, 4-clubs]
# Dealer points: 14
# Dealer hits!
# Dealer draws  jack-clubs
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482379e-09 3.0365085e-11]
# Player has: [7-hearts, 2-spades]
# Player draws:  6-hearts
# Player points:  15
# [0. 1. 0.]
# Player has: [7-hearts, 2-spades, 6-hearts]
# Player sticks on  15
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-diamonds, 2-clubs]
# Dealer points: 9
# Dealer hits!
# Dealer draws  8-clubs
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.5316534e-26 1.0000000e+00 3.0758245e-23]
# Player has: [jack-hearts, 3-diamonds]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-spades, king-spades]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-clubs, 8-clubs]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-diamonds, 2-spades]
# Dealer points: 9
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-clubs, 9-clubs]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-diamonds, 9-clubs]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-hearts, ace-hearts]
# Player sticks on  20
# ...
# Player has: [queen-clubs, 10-hearts]
# Player sticks on  20
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-diamonds, jack-spades]
# Dealer points: 12
# Dealer hits!
# Dealer draws  9-clubs
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.8544457e-05 9.9998140e-01 1.1777747e-10]
# Player has: [2-clubs, 10-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-clubs, 10-spades]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [5-clubs, 7-spades]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-spades, 7-hearts]
# Dealer points: 11
# Dealer hits!
# Dealer draws  9-hearts
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.000000e+00 3.348053e-09 3.036306e-11]
# Player has: [6-spades, 3-hearts]
# Player draws:  king-diamonds
# Player points:  19
# [0. 1. 0.]
# Player has: [6-spades, 3-hearts, king-diamonds]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, 4-clubs]
# Dealer points: 13
# Dealer hits!
# Dealer draws  3-spades
# Dealer points: 16
# Dealer hits!
# Dealer draws  queen-hearts
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [king-hearts, 6-clubs]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-hearts, 8-clubs]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [queen-diamonds, 3-spades]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-spades, 7-hearts]
# Dealer points: 14
# Dealer hits!
# Dealer draws  king-hearts
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, 5-spades]
# Player sticks on  15
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-hearts, 4-diamonds]
# Dealer points: 12
# Dealer hits!
# Dealer draws  king-hearts
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.000000e+00 3.348168e-09 3.036439e-11]
# Player has: [4-clubs, 5-diamonds]
# Player draws:  10-spades
# Player points:  19
# [0. 1. 0.]
# Player has: [4-clubs, 5-diamonds, 10-spades]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-spades, 7-spades]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3482892e-09 3.0365724e-11]
# Player has: [6-clubs, 4-clubs]
# Player draws:  10-hearts
# Player points:  20
# [0. 1. 0.]
# Player has: [6-clubs, 4-clubs, 10-hearts]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-diamonds, ace-hearts]
# Dealer points: 14
# Dealer hits!
# Dealer draws  2-spades
# Dealer points: 16
# Dealer hits!
# Dealer draws  3-clubs
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-diamonds, king-hearts]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-diamonds, 9-clubs]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [4-hearts, king-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-spades, 9-diamonds]
# Dealer points: 14
# Dealer hits!
# Dealer draws  10-hearts
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-hearts, ace-clubs]
# Player sticks on  17
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [7-diamonds, king-spades]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-diamonds, 8-diamonds]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-hearts, 2-hearts]
# Dealer points: 6
# Dealer hits!
# Dealer draws  4-diamonds
# Dealer points: 10
# Dealer hits!
# Dealer draws  6-clubs
# Dealer points: 16
# Dealer hits!
# Dealer draws  3-clubs
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [9-diamonds, king-hearts]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-diamonds, 7-clubs]
# Dealer points: 10
# Dealer hits!
# Dealer draws  5-hearts
# Dealer points: 15
# Dealer hits!
# Dealer draws  2-clubs
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0618807e-05 9.9998939e-01 8.4505423e-11]
# Player has: [10-clubs, 2-hearts]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-spades, 5-hearts]
# Dealer points: 15
# Dealer hits!
# Dealer draws  4-spades
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-clubs, jack-hearts]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, 5-diamonds]
# Dealer points: 9
# Dealer hits!
# Dealer draws  ace-clubs
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [6.080428e-06 9.999939e-01 6.063249e-11]
# Player has: [king-diamonds, 2-hearts]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-diamonds, 10-clubs]
# Dealer points: 12
# Dealer hits!
# Dealer draws  king-clubs
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-spades, 9-diamonds]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-diamonds, 9-spades]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.223311e-07 9.999999e-01 5.925380e-12]
# Player has: [king-clubs, 2-clubs]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-spades, jack-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 3.0302462e-35]
# Player has: [queen-clubs, 4-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-diamonds, 5-spades]
# Dealer points: 15
# Dealer hits!
# Dealer draws  king-diamonds
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-spades, 10-hearts]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [ace-clubs, jack-spades]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-spades, 6-hearts]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-spades, 8-diamonds]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [jack-clubs, 2-diamonds]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-clubs, 8-hearts]
# Dealer points: 10
# Dealer hits!
# Dealer draws  4-clubs
# Dealer points: 14
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3477783e-09 3.0360568e-11]
# Player has: [6-spades, 5-hearts]
# Player draws:  10-hearts
# Player points:  21
# [0. 1. 0.]
# Player has: [6-spades, 5-hearts, 10-hearts]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-hearts, 3-hearts]
# Dealer points: 8
# Dealer hits!
# Dealer draws  queen-clubs
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3479890e-09 3.0362306e-11]
# Player has: [3-clubs, 3-diamonds]
# Player draws:  4-clubs
# Player points:  10
# [1.0000000e+00 3.3481296e-09 3.0363927e-11]
# Player has: [3-clubs, 3-diamonds, 4-clubs]
# Player draws:  ace-clubs
# Player points:  21
# [0. 1. 0.]
# Player has: [3-clubs, 3-diamonds, 4-clubs, ace-clubs]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-clubs, 5-clubs]
# Dealer points: 11
# Dealer hits!
# Dealer draws  2-clubs
# Dealer points: 13
# Dealer hits!
# Dealer draws  3-diamonds
# Dealer points: 16
# Dealer hits!
# Dealer draws  ace-spades
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-clubs, ace-hearts]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-clubs, 8-hearts]
# Dealer points: 16
# Dealer hits!
# Dealer draws  5-spades
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-hearts, 10-clubs]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-hearts, 4-diamonds]
# Dealer points: 14
# Dealer hits!
# Dealer draws  7-hearts
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-spades, jack-clubs]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-diamonds, 7-hearts]
# Dealer points: 10
# Dealer hits!
# Dealer draws  4-hearts
# Dealer points: 14
# Dealer hits!
# Dealer draws  6-diamonds
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [1.4288629e-25 1.0000000e+00 1.1623506e-22]
# Player has: [jack-clubs, 3-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-diamonds, jack-diamonds]
# Dealer points: 16
# Dealer hits!
# Dealer draws  jack-clubs
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3480339e-09 3.0362827e-11]
# Player has: [3-clubs, 4-hearts]
# Player draws:  4-spades
# Player points:  11
# [1.0000000e+00 3.3475485e-09 3.0358369e-11]
# Player has: [3-clubs, 4-hearts, 4-spades]
# Player draws:  2-diamonds
# Player points:  13
# [2.6767973e-26 1.0000000e+00 4.2884801e-23]
# Player has: [3-clubs, 4-hearts, 4-spades, 2-diamonds]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-hearts, 6-diamonds]
# Dealer points: 11
# Dealer hits!
# Dealer draws  ace-hearts
# Dealer points: 12
# Dealer hits!
# Dealer draws  6-spades
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [7-spades, ace-spades]
# Player sticks on  18
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [9-diamonds, 9-clubs]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, ace-diamonds]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [jack-diamonds, 7-diamonds]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-diamonds, ace-clubs]
# Player sticks on  19
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [5-clubs, king-hearts]
# Dealer points: 15
# Dealer hits!
# Dealer draws  7-clubs
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-diamonds, queen-spades]
# Player sticks on  20
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-clubs, 5-diamonds]
# Dealer points: 7
# Dealer hits!
# Dealer draws  8-hearts
# Dealer points: 15
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 24
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-spades, 8-spades]
# Player sticks on  18
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-clubs, 9-hearts]
# Dealer points: 12
# Dealer hits!
# Dealer draws  10-clubs
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [ace-clubs, 10-spades]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-hearts, queen-hearts]
# Dealer points: 16
# Dealer hits!
# Dealer draws  10-hearts
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [6-diamonds, king-spades]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-clubs, 3-clubs]
# Dealer points: 11
# Dealer hits!
# Dealer draws  10-diamonds
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 3.0302462e-35]
# Player has: [5-diamonds, 9-hearts]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-diamonds, 7-spades]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-diamonds, ace-diamonds]
# Player sticks on  21
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [king-hearts, ace-clubs]
# Dealer points: 21
# Dealer sticks.
# ======== PLAYER TURN ========
# [0.0000000e+00 1.0000000e+00 1.5588021e-35]
# Player has: [10-diamonds, 4-spades]
# Player sticks on  14
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [2-spades, jack-diamonds]
# Dealer points: 12
# Dealer hits!
# Dealer draws  4-diamonds
# Dealer points: 16
# Dealer hits!
# Dealer draws  jack-hearts
# Dealer points: 26
# Dealer Bust!
# ======== PLAYER TURN ========
# [1.0000000e+00 3.3479954e-09 3.0362421e-11]
# Player has: [5-diamonds, 4-clubs]
# Player draws:  4-hearts
# Player points:  13
# [2.4971742e-25 1.0000000e+00 1.6206300e-22]
# Player has: [5-diamonds, 4-clubs, 4-hearts]
# Player sticks on  13
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-diamonds, jack-diamonds]
# Dealer points: 20
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.8693523e-27 1.0000000e+00 1.1348179e-23]
# Player has: [8-spades, 5-hearts]
# Player sticks on  13
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [4-diamonds, 2-spades]
# Dealer points: 6
# Dealer hits!
# Dealer draws  9-spades
# Dealer points: 15
# Dealer hits!
# Dealer draws  queen-clubs
# Dealer points: 25
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [5-spades, ace-diamonds]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [6-diamonds, 7-hearts]
# Dealer points: 13
# Dealer hits!
# Dealer draws  9-diamonds
# Dealer points: 22
# Dealer Bust!
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [jack-clubs, 6-spades]
# Player sticks on  16
# WINNER ////// Player won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [10-hearts, 7-hearts]
# Dealer points: 17
# Dealer sticks.
# ======== PLAYER TURN ========
# [2.1379280e-07 9.9999976e-01 8.2614983e-12]
# Player has: [ace-clubs, ace-diamonds]
# Player sticks on  12
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [queen-spades, 9-hearts]
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [8-diamonds, 8-spades]
# Player sticks on  16
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [3-hearts, 6-diamonds]
# Dealer points: 9
# Dealer hits!
# Dealer draws  queen-clubs
# Dealer points: 19
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [10-clubs, 9-clubs]
# Player sticks on  19
# WINNER +++++ Dealer won!
# ========= STARTING =========
# ======== DEALER TURN ========
# Dealer has:  [8-diamonds, queen-clubs]
# Dealer points: 18
# Dealer sticks.
# ======== PLAYER TURN ========
# [0. 1. 0.]
# Player has: [queen-hearts, queen-spades]
# Player sticks on  20
# WINNER ////// Player won!
# -0.856
# -1100

# %% [markdown]
# #Save Agent

# %%
agent.model.save_weights("model.h5")
agent.target_model.save_weights("target_model.h5")
